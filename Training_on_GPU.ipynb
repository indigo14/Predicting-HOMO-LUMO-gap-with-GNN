# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayak2019/ml_for_molecules/blob/main/Training_on_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here, we will train the graph neural network model on GPU. Most of the code here is from the previous lessons.

# %%
# install dgl, rdkit and fast-ml
#! pip install  dgl -f https://data.dgl.ai/wheels/cu118/repo.html
! pip install  dglgo -f https://data.dgl.ai/wheels-test/repo.html
! pip install dgllife
! pip install rdkit
! pip install fast_ml
# Out:
# Looking in links: https://data.dgl.ai/wheels-test/repo.html
# Requirement already satisfied: dglgo in c:\spdp\graph neural network\pppvenv\lib\site-packages (0.0.2)
# Requirement already satisfied: typer>=0.4.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (0.12.3)
# Requirement already satisfied: isort>=5.10.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (5.13.2)
# Requirement already satisfied: autopep8>=1.6.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (2.3.1)
# Requirement already satisfied: numpydoc>=1.1.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (1.7.0)
# Requirement already satisfied: pydantic>=1.9.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (2.8.2)
# Requirement already satisfied: ruamel.yaml>=0.17.20 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (0.18.6)
# Requirement already satisfied: PyYAML>=5.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (6.0.1)
# Requirement already satisfied: ogb>=1.3.3 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (1.3.6)
# Requirement already satisfied: rdkit-pypi in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (2022.9.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dglgo) (1.5.1)
# Requirement already satisfied: pycodestyle>=2.12.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from autopep8>=1.6.0->dglgo) (2.12.0)
# Requirement already satisfied: sphinx>=6 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from numpydoc>=1.1.0->dglgo) (7.4.7)
# Requirement already satisfied: tabulate>=0.8.10 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from numpydoc>=1.1.0->dglgo) (0.9.0)
# Requirement already satisfied: torch>=1.6.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (2.1.2+cu121)
# Requirement already satisfied: numpy>=1.16.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (4.66.4)
# Requirement already satisfied: pandas>=0.24.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (2.2.2)
# Requirement already satisfied: outdated>=0.2.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ogb>=1.3.3->dglgo) (0.2.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pydantic>=1.9.0->dglgo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pydantic>=1.9.0->dglgo) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pydantic>=1.9.0->dglgo) (4.12.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from ruamel.yaml>=0.17.20->dglgo) (0.2.8)
# Requirement already satisfied: scipy>=1.6.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from scikit-learn>=0.20.0->dglgo) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from scikit-learn>=0.20.0->dglgo) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from scikit-learn>=0.20.0->dglgo) (3.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from typer>=0.4.0->dglgo) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from typer>=0.4.0->dglgo) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from typer>=0.4.0->dglgo) (13.7.1)
# Requirement already satisfied: Pillow in c:\spdp\graph neural network\pppvenv\lib\site-packages (from rdkit-pypi->dglgo) (10.4.0)
# Requirement already satisfied: colorama in c:\spdp\graph neural network\pppvenv\lib\site-packages (from click>=8.0.0->typer>=0.4.0->dglgo) (0.4.6)
# Requirement already satisfied: setuptools>=44 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (65.5.0)
# Requirement already satisfied: littleutils in c:\spdp\graph neural network\pppvenv\lib\site-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (0.2.4)
# Requirement already satisfied: requests in c:\spdp\graph neural network\pppvenv\lib\site-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from rich>=10.11.0->typer>=0.4.0->dglgo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from rich>=10.11.0->typer>=0.4.0->dglgo) (2.18.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.0.6)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.8)
# Requirement already satisfied: Jinja2>=3.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (3.1.3)
# Requirement already satisfied: docutils<0.22,>=0.20 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: babel>=2.13 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: packaging>=23.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (24.1)
# Requirement already satisfied: filelock in c:\spdp\graph neural network\pppvenv\lib\site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.13.1)
# Requirement already satisfied: sympy in c:\spdp\graph neural network\pppvenv\lib\site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (1.12)
# Requirement already satisfied: networkx in c:\spdp\graph neural network\pppvenv\lib\site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.3)
# Requirement already satisfied: fsspec in c:\spdp\graph neural network\pppvenv\lib\site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from Jinja2>=3.1->sphinx>=6->numpydoc>=1.1.0->dglgo) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.4.0->dglgo) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from sympy->torch>=1.6.0->ogb>=1.3.3->dglgo) (1.3.0)
# Requirement already satisfied: dgllife in c:\spdp\graph neural network\pppvenv\lib\site-packages (0.3.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (1.5.1)
# Requirement already satisfied: pandas in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (2.2.2)
# Requirement already satisfied: requests>=2.22.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (2.32.3)
# Requirement already satisfied: tqdm in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (4.66.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (1.14.0)
# Requirement already satisfied: networkx>=2.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (3.3)
# Requirement already satisfied: hyperopt in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (0.2.7)
# Requirement already satisfied: joblib in c:\spdp\graph neural network\pppvenv\lib\site-packages (from dgllife) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests>=2.22.0->dgllife) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests>=2.22.0->dgllife) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests>=2.22.0->dgllife) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from requests>=2.22.0->dgllife) (2024.7.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from scikit-learn>=0.22.2->dgllife) (3.5.0)
# Requirement already satisfied: six in c:\spdp\graph neural network\pppvenv\lib\site-packages (from hyperopt->dgllife) (1.16.0)
# Requirement already satisfied: future in c:\spdp\graph neural network\pppvenv\lib\site-packages (from hyperopt->dgllife) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\spdp\graph neural network\pppvenv\lib\site-packages (from hyperopt->dgllife) (3.0.0)
# Requirement already satisfied: py4j in c:\spdp\graph neural network\pppvenv\lib\site-packages (from hyperopt->dgllife) (0.10.9.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas->dgllife) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas->dgllife) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from pandas->dgllife) (2024.1)
# Requirement already satisfied: colorama in c:\spdp\graph neural network\pppvenv\lib\site-packages (from tqdm->dgllife) (0.4.6)
# Requirement already satisfied: rdkit in c:\spdp\graph neural network\pppvenv\lib\site-packages (2024.3.3)
# Requirement already satisfied: numpy<2.0 in c:\spdp\graph neural network\pppvenv\lib\site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in c:\spdp\graph neural network\pppvenv\lib\site-packages (from rdkit) (10.4.0)
# Requirement already satisfied: fast_ml in c:\spdp\graph neural network\pppvenv\lib\site-packages (3.68)

# %%
# import pandas library
import pandas as pd

# load the dataframe as CSV from URL. 
df = pd.read_csv("https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/qm9.csv")

# create the dataset with smiles and gap
# we will use a 5% of the dataset to save time
dataset = df[["smiles","gap"]].sample(frac=0.05)

# import from rdkit and dgl-lifesci
from rdkit import Chem
from dgllife.utils import CanonicalAtomFeaturizer, CanonicalBondFeaturizer, \
mol_to_bigraph

# create the atom and bond featurizer object
atom_featurizer = CanonicalAtomFeaturizer(atom_data_field="hv")
bond_featurizer = CanonicalBondFeaturizer(bond_data_field="he")


# helper function to convert smiles to graph
def smiles2graph(smiles):
  mol = Chem.MolFromSmiles(smiles)
  graph = mol_to_bigraph(mol, node_featurizer=atom_featurizer, 
                     edge_featurizer=bond_featurizer)
  return graph

# add graphs to dataframe
dataset["graph"] = dataset["smiles"].apply(smiles2graph)


# import the function to split into train-valid-test
from fast_ml.model_development import train_valid_test_split

X_train, y_train, X_valid, y_valid, \
X_test, y_test = train_valid_test_split(dataset[["graph","gap"]], 
                                        target = "gap", 
                                        train_size=0.8,
                                        valid_size=0.1, 
                                        test_size=0.1) 

# creating dataloader

import dgl

def collate_data(data):
  # our data is in the form of list of (X,y)
  # the map function thus maps accordingly
  graphs, y = map(list, zip(*data))

  # for creating a batch of graph, we use the batch function
  batch_graph = dgl.batch(graphs)

  # we need to stack the ys for different entries in the batch
  y = torch.stack(y, dim=0)

  return batch_graph, y


# import dataloader
import torch
from torch.utils.data import DataLoader

# create the dataloader for train dataset
# dataset should be of form (X,y) according to the collate function
# the ys should also be converted to tensors
train_dataloader = DataLoader(
    dataset=list(zip(X_train["graph"].values.tolist(),
                     torch.tensor(y_train.tolist(), dtype=torch.float32))),
    batch_size=64, collate_fn=collate_data)

valid_dataloader = DataLoader(
    dataset=list(zip(X_valid["graph"].values.tolist(),
                     torch.tensor(y_valid.tolist(), dtype=torch.float32))),
    batch_size=64, collate_fn=collate_data)

test_dataloader = DataLoader(
    dataset=list(zip(X_test["graph"].values.tolist(),
                     torch.tensor(y_test.tolist(), dtype=torch.float32))),
    batch_size=64, collate_fn=collate_data)


# import MLP model from dgl-lifesci
from dgllife.model.model_zoo.mpnn_predictor import MPNNPredictor

# the atom feature length is 74 and bond is 12
model = MPNNPredictor(node_in_feats = 74, 
                      edge_in_feats = 12, 
                      node_out_feats = 64, 
                      edge_hidden_feats = 128,
                      n_tasks = 1,
                      num_step_message_passing = 6,
                      num_step_set2set = 6,
                      num_layer_set2set = 3)


# loss function for regresssion is usually mean squared error
import torch

loss_func = torch.nn.MSELoss(reduce=None)


# adam optimier
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# By default, the tensors ar on cpu. We need to transfer them to GPU. All the tensors must be on the same device before doing any operation.

# %%
epochs = 5

################# tranfer model to GPU #################
model.to(device="cuda:0")
#############################################################


# loop over epochs
for epoch in range(epochs):
  print("\nStarting Epoch", epoch+1)

  # set the model to train so the parameters can be updated
  model.train()
  # loop over training batches

  train_loss = []
  for batch in train_dataloader: 

    # Do a forward pass
    batch_graph, target = batch

    # look at the forward function for input
    # this model needs graph, node_feats and edge_feats
    node_feats = batch_graph.ndata["hv"]
    edge_feats = batch_graph.edata["he"]

    ############# transfer to GPU #################
    batch_graph = batch_graph.to(device="cuda:0")
    edge_feats = edge_feats.to(device="cuda:0")
    node_feats = node_feats.to(device="cuda:0")
    target = target.to(device="cuda:0")
    ##############################################

    predictions = model(batch_graph, node_feats, edge_feats)
  
    # Compute loss
    loss = (loss_func(predictions, target)).mean()
    optimizer.zero_grad()

    # Do back propogation and update gradient
    loss.backward()
    optimizer.step()

    # save loss to compute average loss
    train_loss.append(loss)

  print("Training loss", torch.tensor(train_loss).mean().item())


  # set the model to eval so the parameters are not updated
  model.eval()
  valid_loss = []

  # loop over validation batches
  with torch.no_grad():
    for batch in valid_dataloader:
      
      # Do a forward pass
      batch_graph, target = batch
      node_feats = batch_graph.ndata["hv"]
      edge_feats = batch_graph.edata["he"]

      ############# transfer to GPU #################
      batch_graph = batch_graph.to(device="cuda:0")
      edge_feats = edge_feats.to(device="cuda:0")
      node_feats = node_feats.to(device="cuda:0")
      target = target.to(device="cuda:0")
      ##############################################

      predictions = model(batch_graph, node_feats, edge_feats)
    
      # Compute loss and gradient
      loss = (loss_func(predictions, target)).mean()

      # save loss to compute average loss
      valid_loss.append(loss)
      
  print("Validation loss ", torch.tensor(valid_loss).mean().item())
# Out:
# Starting Epoch 1
# Training loss 0.005135665647685528
# Validation loss  0.0021944427862763405
#
# Starting Epoch 2
# Training loss 0.002302614040672779
# Validation loss  0.0021908192429691553
#
# Starting Epoch 3
# Training loss 0.0022973089944571257
# Validation loss  0.0021898087579756975
#
# Starting Epoch 4
# Training loss 0.002295795828104019
# Validation loss  0.0021890790667384863
#
# Starting Epoch 5
# Training loss 0.0022946971002966166
# Validation loss  0.0021889356430619955

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# True
# 12.1
